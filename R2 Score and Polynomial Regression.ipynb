# %%
import pandas as pd

# %%
data = [[1,0,0.002], [2,20,0.0012], [3,30,0.06]]

df = pd.DataFrame(data,columns=["sn","tem","pres"])

df
# Out:
#    sn  tem    pres
# 0   1    0  0.0020
# 1   2   20  0.0012
# 2   3   30  0.0600

# %%
x = df.iloc[:,1:2].values

# %%
x
# Out:
# array([[ 0],
#        [20],
#        [30]])

# %%
y = df.iloc[:,2].values

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()

regressor.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x)

y_pred
# Out:
# array([-0.00645714,  0.02657143,  0.04308571])

# %%
import matplotlib.pyplot as plt

tem =  df['tem'].tolist()

pre = df ['pres'].tolist()

plt.plot(tem,pre,color='blue')

plt.scatter(tem,y_pred, color='red')

plt.xlabel('temparature')

plt.ylabel('pressure')

plt.xticks(tem)

plt.title('simple linear regression')

plt.yticks(pre)

plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
y=mx+c

#polynomial regression

y-ax+c

yax2+bx+c dgree - 2

y=ax^3+bx2+cx+d

y =
# Out:
#   File "<ipython-input-9-d6e54bc9f861>", line 7
#     yax2+bx+c dgree - 2
#               ^
# SyntaxError: invalid syntax

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree = 4)

x_poly = poly.fit_transform(x)

x_poly
# Out:
# array([[1.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00],
#        [1.0e+00, 2.0e+01, 4.0e+02, 8.0e+03, 1.6e+05],
#        [1.0e+00, 3.0e+01, 9.0e+02, 2.7e+04, 8.1e+05]])

# %% [markdown]
# If degree is the number of features = 4
#
# then degree is N then the number of feature is N+1

# %%
lin = LinearRegression()

lin.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
y_poly = lin.predict(x_poly)

y_poly
# Out:
# array([0.002 , 0.0012, 0.06  ])

# %%
import matplotlib.pyplot as plt

tem = df['tem'].tolist()

pre = df['pres'].tolist()

plt.plot(tem,pre,color='blue')

plt.scatter(tem,y_poly, color='red')

plt.xlabel('temparature')

plt.ylabel('pressure')

plt.xticks(tem)

plt.title('simple linear regression')

plt.yticks(pre)

plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df = pd.DataFrame({'actual_value' : y, 'predicted_value': y_pred, 'polynomial value': y_poly})

df
# Out:
#    actual_value  predicted_value  polynomial value
# 0        0.0020        -0.006457            0.0020
# 1        0.0012         0.026571            0.0012
# 2        0.0600         0.043086            0.0600

# %%
from sklearn.metrics import r2_score

print('simple linear regression', r2_score(y,y_pred))
print('polynomial regression', r2_score(y,y_poly))
# Out:
# simple linear regression 0.5596684379460306
# polynomial regression 1.0

# %%
tem = int(input("input enter the temp"))

x_new = poly.fit_transform([[tem]])
# Out:
# input enter the temp27

# %%
x_new
# Out:
# array([[1.00000e+00, 2.70000e+01, 7.29000e+02, 1.96830e+04, 5.31441e+05]])

# %%
lin.predict(x_new)
# Out:
# array([0.0310167])
